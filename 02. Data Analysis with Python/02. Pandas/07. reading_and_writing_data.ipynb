# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_table("data.txt")

# %%
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
df2 = pd.read_table("data2.txt")

# %%
df2
# Out:
#     Tom,80,M
# 0   Tim,85,M
# 1   Kim,70,M
# 2  Kate,90,F
# 3  Alex,75,F

# %%
df2 = pd.read_table("data2.txt", sep=",", header=None)
df2
# Out:
#       0   1  2
# 0   Tom  80  M
# 1   Tim  85  M
# 2   Kim  70  M
# 3  Kate  90  F
# 4  Alex  75  F

# %%
df2 = pd.read_table("data2.txt", sep=",", header=None, names=["name", "score", "gender"])
df2
# Out:
#    name  score gender
# 0   Tom     80      M
# 1   Tim     85      M
# 2   Kim     70      M
# 3  Kate     90      F
# 4  Alex     75      F

# %%
df2 = pd.read_table("data2.txt", sep=",", header=None, names=["name", "score", "gender"], index_col="name")
df2
# Out:
#       score gender
# name
# Tom      80      M
# Tim      85      M
# Kim      70      M
# Kate     90      F
# Alex     75      F

# %%
df2 = pd.read_table("data3.txt", sep=",")
df2
# Out:
#   lesson  name  one  two
# 0   Math   Kim   80   85
# 1   Math   Tim   90   70
# 2   Math   Tom   70   95
# 3   Stat  Kate   65   90
# 4   Stat  Alex   85   80
# 5   Stat   Sam   55   70

# %%
df2 = pd.read_table("data3.txt", sep=",", index_col=["lesson", "name"])
df2
# Out:
#              one  two
# lesson name
# Math   Kim    80   85
#        Tim    90   70
#        Tom    70   95
# Stat   Kate   65   90
#        Alex   85   80
#        Sam    55   70

# %%
# writing data with pandas
df = pd.read_csv("data.txt", sep="\t")
df
# Out:
#   name  score sex
# 0  Tim     80   M
# 1  Tom     85   M
# 2  Kim     70   F
# 3  Sam     90   M
# 4  Efe     75   M

# %%
df.to_csv("new_data.csv")
